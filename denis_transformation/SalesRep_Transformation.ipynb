# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Generic"

# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Connectors"

# %%
adls_connect()

# %%
from pyspark.sql import functions as F

# %%
list_bronze_files()

# %%
salesRep_df = read_bronze_file_csv("SalesRep")

# %% [markdown]
# ### Transformation

# %%
rows_and_columns_count(salesRep_df)

# %%
check_duplicates(salesRep_df,salesRep_df.columns)

# %%
# Formatting SalesRepID to only digits
salesRep_df = salesRep_df.withColumn("SalesRepID", F.regexp_extract(F.col("SalesRepID"), r"(\d+)", 1))

# %%
# Replacing space seperated column names to single column name
salesRep_df = salesRep_df.withColumnRenamed("Sales Rep Name", "SalesRepName")

# %% [markdown]
# ### Writing to Silver layer

# %%
write_to_silver(salesRep_df, "salesRep_S.csv")
