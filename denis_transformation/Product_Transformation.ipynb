# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Generic"

# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Connectors"

# %%
from pyspark.sql import functions as F

# %%
adls_connect()

# %%
list_bronze_files()

# %%
product_df = read_bronze_file_csv("`product`")

# %%
display(product_df.limit(5))

# %%
rows_and_columns_count(product_df)

# %%
check_duplicates(product_df,product_df.columns)

# %%
check_missing_values(product_df,product_df.columns)

# %%
check_missing_values_percentage(product_df,product_df.columns)

# %%
check_missing_values_percentage_v1(product_df,product_df.columns)

# %%
check_string_value_as_nan(product_df)

# %% [markdown]
# ### Transformation

# %%
# Removing duplicate Product IDs
product_df = product_df.groupBy("ProductID","ProductName","Sub Category Key","Color","RetailPrice","StandardCost").agg(
    F.count("ProductID").alias("DistinctProductID")
)

# %%
display(product_df)

# %%
# Selected columns after removing duplicate IDs
product_df = product_df.select("ProductID","ProductName","Sub Category Key","Color","RetailPrice","StandardCost")

# %%
display(product_df)

# %%
product_df = product_df.sort(F.col("ProductID"), asc=True)

# %%
display(product_df)

# %% [markdown]
# ### Writing to Silver layer

# %%
write_to_silver(product_df, "product_S.csv")
