# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Generic"

# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Connectors"

# %%
from pyspark.sql import functions as F

# %%
adls_connect()

# %%
list_bronze_files()

# %%
cat_df = read_bronze_file_xlsx("Categories")

# %%
display(cat_df.limit(5))

# %%
rows_and_columns_count(cat_df)

# %%
check_duplicates(cat_df,cat_df.columns)

# %%
check_missing_values(cat_df,cat_df.columns)

# %%
check_missing_values_percentage(cat_df,cat_df.columns)

# %%
check_missing_values_percentage_v1(cat_df,cat_df.columns)

# %%
check_string_value_as_nan(cat_df)

# %% [markdown]
# ### Writing to Silver layer

# %%
write_to_silver(cat_df, "categories_S.csv")
