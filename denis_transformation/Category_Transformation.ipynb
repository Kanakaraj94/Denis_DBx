# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Generic"

# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Connectors"

# %%
from pyspark.sql import functions as F

# %%
adls_connect()

# %%
list_bronze_files()

# %%
cat_df = read_bronze_file_xlsx("Categories")

# %%
check_duplicates(cat_df,cat_df.columns)

# %% [markdown]
# ### Writing to Silver layer

# %%
write_to_silver(cat_df, "categories_S.csv")
