# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Generic"

# %%
# %run "/Workspace/Denis_Databricks/Denis_DBx/denis_transformation/Connectors"

# %%
from pyspark.sql import functions as F

# %%
adls_connect()

# %%
list_bronze_files()

# %%
subCat_df = read_bronze_file_csv("SubCategories")

# %% [markdown]
# ### Transformation

# %%
# Formatting CategoryKey to only digits
subCat_df = subCat_df.withColumn("CategoryKey", F.regexp_extract(F.col("CategoryKey"), r"(\d+)", 1))

# %% [markdown]
# ### Writing to Silver layer

# %%
write_to_silver(subCat_df, "subCategories_S.csv")
